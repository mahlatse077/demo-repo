# %%
import pandas as pd

# %%
df=pd.read_csv('transaction.csv', sep = ';')

# %%
df
# Out:
#          UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0        278166        6355745  2019   Feb    2  12:50:00    465549
# 1        337701        6283376  2018   Dec   26  09:06:00    482370
# 2        267099        6385599  2019   Feb   15  09:45:00    490728
# 3        380478        6044973  2018   Jun   22  07:14:00    459186
# 4            -1        6143225  2018   Sep   10  11:58:00   1733592
# ...         ...            ...   ...   ...  ...       ...       ...
# 1047583  343560        6386952  2019   Feb   16  08:16:00    450030
# 1047584  276528        6316717  2019   Jan   15  08:56:00   1732143
# 1047585  341082        6140585  2018   Sep    8  10:41:00    487326
# 1047586  336147        6075190  2018   Jul   20  09:32:00    460509
# 1047587      -1        6180020  2018   Oct   10  12:00:00    473739
#
#                             ItemDescription  NumberOfItemsPurchased  \
# 0          FAMILY ALBUM WHITE PICTURE FRAME                       6
# ...

# %% [markdown]
# Question 2

# %%
df['CostPerTransaction']=df['CostPerItem']*df['NumberOfItemsPurchased']

# %%
df.head(3)
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# 2                 1.62          France
#
#                                       ClientKeywords  CostPerTransaction
# 0  ['Senior', 'Solo Entrepreneur', '2-5 Year Clie...               70.38
# 1   ['Middle Age', 'Corporation', '2-5 Year Client']               10.56
# ...

# %% [markdown]
# Question 3

# %%
df['SalesPerTransaction']=df['NumberOfItemsPurchased']*df['SellingPricePerItem']

# %%
df.head(4)
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
# 3  380478        6044973  2018   Jun   22  07:14:00    459186
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# 2                 1.62          France
# 3                 1.90  United Kingdom
#
#                                       ClientKeywords  CostPerTransaction  \
# ...

# %% [markdown]
# Question 4

# %%
df[' ProfitPerTransaction']=df['SalesPerTransaction']-df['CostPerTransaction']

# %%
df.head(4)
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
# 3  380478        6044973  2018   Jun   22  07:14:00    459186
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# 2                 1.62          France
# 3                 1.90  United Kingdom
#
#                                       ClientKeywords  CostPerTransaction  \
# ...

# %% [markdown]
# Question 5

# %%
df[' ProfitPerTransaction']=df[' ProfitPerTransaction'].round()

# %%
df.head(4)
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
# 3  380478        6044973  2018   Jun   22  07:14:00    459186
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# 2                 1.62          France
# 3                 1.90  United Kingdom
#
#                                       ClientKeywords  CostPerTransaction  \
# ...

# %% [markdown]
# Question 6

# %%
df['Year']=df['Year'].astype(str)

# %%
df['Day']=df['Day'].astype(str)

# %%
df['day-month-year']=df['Day']+'-'+df['Month']+'-'+df['Year']

# %%
df.head(4)
# Out:
#    UserId  TransactionId  Year Month Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb   2  12:50:00    465549
# 1  337701        6283376  2018   Dec  26  09:06:00    482370
# 2  267099        6385599  2019   Feb  15  09:45:00    490728
# 3  380478        6044973  2018   Jun  22  07:14:00    459186
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# 2                 1.62          France
# 3                 1.90  United Kingdom
#
#                                       ClientKeywords  CostPerTransaction  \
# ...

# %% [markdown]
# Question 7

# %%
df['ItemDescription']=df['ItemDescription'].str.lower()

# %%
df.head(4)
# Out:
#    UserId  TransactionId  Year Month Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb   2  12:50:00    465549
# 1  337701        6283376  2018   Dec  26  09:06:00    482370
# 2  267099        6385599  2019   Feb  15  09:45:00    490728
# 3  380478        6044973  2018   Jun  22  07:14:00    459186
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   family album white picture frame                       6        11.73
# 1              london bus coffee mug                       3         3.52
# 2  set 12 colour pencils dolly girl                       72         0.90
# 3        union jack flag luggage tag                       3         1.73
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# 2                 1.62          France
# 3                 1.90  United Kingdom
#
#                                       ClientKeywords  CostPerTransaction  \
# ...

# %% [markdown]
# Question 8

# %%
df[['ClientAge','ClientType','LengthofContract']]=df['ClientKeywords'].str.split(',', expand=True)

# %%
df.head(4)
# Out:
#    UserId  TransactionId  Year Month Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb   2  12:50:00    465549
# 1  337701        6283376  2018   Dec  26  09:06:00    482370
# 2  267099        6385599  2019   Feb  15  09:45:00    490728
# 3  380478        6044973  2018   Jun  22  07:14:00    459186
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   family album white picture frame                       6        11.73
# 1              london bus coffee mug                       3         3.52
# 2  set 12 colour pencils dolly girl                       72         0.90
# 3        union jack flag luggage tag                       3         1.73
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# 2                 1.62          France
# 3                 1.90  United Kingdom
#
#                                       ClientKeywords  CostPerTransaction  \
# ...

# %%
df.drop('ClientKeywords', axis='columns', inplace=True)

# %%
df['ClientAge'] = df['ClientAge'].str.replace('\W', '')
# Out:
# C:\Users\zsk\AppData\Local\Temp\ipykernel_20392\1674420723.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['ClientAge'] = df['ClientAge'].str.replace('\W', '')

# %%
df['ClientType'] = df['ClientType'].str.replace('\W', '')
# Out:
# C:\Users\zsk\AppData\Local\Temp\ipykernel_20392\87546293.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['ClientType'] = df['ClientType'].str.replace('\W', '')

# %%
df['LengthofContract'] = df['LengthofContract'].str.replace('\W', '')
# Out:
# C:\Users\zsk\AppData\Local\Temp\ipykernel_20392\649429078.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['LengthofContract'] = df['LengthofContract'].str.replace('\W', '')

# %%
df.head()
# Out:
#    UserId  TransactionId  Year Month Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb   2  12:50:00    465549
# 1  337701        6283376  2018   Dec  26  09:06:00    482370
# 2  267099        6385599  2019   Feb  15  09:45:00    490728
# 3  380478        6044973  2018   Jun  22  07:14:00    459186
# 4      -1        6143225  2018   Sep  10  11:58:00   1733592
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   family album white picture frame                       6        11.73
# 1              london bus coffee mug                       3         3.52
# 2  set 12 colour pencils dolly girl                       72         0.90
# 3        union jack flag luggage tag                       3         1.73
# 4                washroom metal sign                       3         3.40
#
#    SellingPricePerItem         Country  CostPerTransaction  \
# 0                21.11  United Kingdom               70.38
# ...
